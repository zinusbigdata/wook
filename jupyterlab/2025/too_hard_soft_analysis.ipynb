# %% [markdown]
# # Too Hard / Soft Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pytz
from datetime import datetime, timedelta
import os
import sys
import io
from io import BytesIO
import csv
import google.auth
from google.cloud import bigquery
#from google.cloud import bigquery_storage

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./market-analysis-project-91130-9f9a036682b6.json"

credentials, project_id = google.auth.default(
    scopes=["https://www.googleapis.com/auth/cloud-platform"]
)

bqclient = bigquery.Client(credentials=credentials, project=project_id,)
#bqstorageclient = bigquery_storage.BigQueryReadClient(credentials=credentials)

# %%
sql = f"""
    select * from mart.amz_us_zinus_crwl_rpa_rvw
    where cf1 is not null
"""

df = bqclient.query(sql).to_dataframe()

# %%
df
# Out:
#                      sku               category     financial_category  \
# 0                ADB-14F  Frames for Mattresses          Platform Beds
# 1                ADB-14F  Frames for Mattresses          Platform Beds
# 2                ADB-14F  Frames for Mattresses          Platform Beds
# 3                ADB-14F  Frames for Mattresses          Platform Beds
# 4                ADB-14F  Frames for Mattresses          Platform Beds
# ...                  ...                    ...                    ...
# 42318      ZU-USSMC1-74D              Furniture                   Sofa
# 42319      ZU-USSMC1-74D              Furniture                   Sofa
# 42320      ZU-UTOTV2-16B              Furniture  Non Bedroom Furniture
# 42321      ZU-UTOTV3-16E              Furniture  Non Bedroom Furniture
# 42322  SM-SC-SBBK-14F-FR             SmartBases             SmartBases
#
#       detailed_category          collection        asin        date yr_month  \
# ...

# %%
df

# %%
df = pd.read_csv("review-vc_sales_by_collection.csv")

# %%
foam_df = df[df['financial_category'] == 'Foam Mattresses']

# %%
foam_df = foam_df[foam_df['collection'] == '__TOTAL__']

# %%
foam_df.to_csv('foam_df_2_hard_soft.csv')

# %%
foam_df
# Out:
#        yr_month financial_category collection  written_avg_rating  \
# 31       202201    Foam Mattresses  __TOTAL__            3.314070
# 449      202202    Foam Mattresses  __TOTAL__            3.188732
# 863      202203    Foam Mattresses  __TOTAL__            3.400485
# 1279     202204    Foam Mattresses  __TOTAL__            3.474860
# 1711     202205    Foam Mattresses  __TOTAL__            3.604317
# 2259     202206    Foam Mattresses  __TOTAL__            3.659722
# 2820     202207    Foam Mattresses  __TOTAL__            3.779264
# 3383     202208    Foam Mattresses  __TOTAL__            3.692192
# 3950     202209    Foam Mattresses  __TOTAL__            3.747706
# 4520     202210    Foam Mattresses  __TOTAL__            3.522801
# 5091     202211    Foam Mattresses  __TOTAL__            3.475200
# 5666     202212    Foam Mattresses  __TOTAL__            3.257660
# 6246     202301    Foam Mattresses  __TOTAL__            3.522367
# ...

# %% [markdown]
# ## too hard / soft

# %%
df1 = pd.read_csv("review_sales_too_hard_soft.csv")

# %%
df1
# Out:
#      Unnamed: 0  yr_month     financial_category  written_avg_rating  \
# 0             0    202212             SmartBases            4.038674
# 1             1    202412          Platform Beds            3.854545
# 2             2    202309                Toppers            3.106061
# 3             3    202201  Non Bedroom Furniture            3.853333
# 4             4    202411                 Others            5.000000
# ..          ...       ...                    ...                 ...
# 385         385    202303                Toppers            2.700637
# 386         386    202311            Box Springs            3.840206
# 387         387    202202            Box Springs            4.133739
# 388         388    202401                Toppers            3.041667
# 389         389    202408  Non Bedroom Furniture            4.125000
#
#      written_12_cnt  written_all_cnt  written_12_ratio  all_avg_rating  \
# ...

# %%
foam_df1 = df1[df1['financial_category'] == 'Foam Mattresses']

# %%
foam_df1
# Out:
#      Unnamed: 0  yr_month financial_category  written_avg_rating  \
# 8             8    202207    Foam Mattresses            3.779264
# 10           10    202310    Foam Mattresses            3.620219
# 11           11    202301    Foam Mattresses            3.522367
# 18           18    202401    Foam Mattresses            3.507194
# 37           37    202502    Foam Mattresses            3.118203
# 41           41    202203    Foam Mattresses            3.400485
# 44           44    202501    Foam Mattresses            3.205285
# 51           51    202409    Foam Mattresses            3.676230
# 59           59    202302    Foam Mattresses            3.476923
# 88           88    202307    Foam Mattresses            3.631670
# 102         102    202212    Foam Mattresses            3.257660
# 112         112    202403    Foam Mattresses            3.616628
# 126         126    202402    Foam Mattresses            3.549261
# ...
